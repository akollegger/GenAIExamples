# %%
from neo4j import GraphDatabase, basic_auth
import neo4j
import time
import aiohttp
import asyncio
import json
import os
from dotenv import load_dotenv
from pathlib import Path

# %%
#load the environment variables
dotenv_path = Path('../.env')
load_dotenv(dotenv_path=dotenv_path)  # This line brings all environment variables from .env into os.environ

# Get variables
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_USER = os.getenv('NEO4J_USER')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')

# Connect to database
driver = GraphDatabase.driver(NEO4J_URI, auth=basic_auth(NEO4J_USER, NEO4J_PASSWORD))
print(driver.verify_connectivity())
# Out:
# None

# %% [markdown]
# ### Constaints

# %%
def create_constraint(tx,statement):
    tx.run(statement)

# %% [markdown]
# > Uniqueness

# %%
statement_goal = """ 
CREATE CONSTRAINT goal_unique IF NOT EXISTS FOR (goal:Goal) 
REQUIRE (goal.code,goal.title,goal.description) IS NODE KEY;
"""
statement_target="""
CREATE CONSTRAINT target_unique IF NOT EXISTS FOR (t:Target) 
REQUIRE (t.code,t.title,t.description) IS NODE KEY;
"""
statement_indicator ="""
CREATE CONSTRAINT indicator_unique IF NOT EXISTS FOR (i:Indicator) 
REQUIRE (i.code,i.description) IS NODE KEY;
"""

statement_series ="""
CREATE CONSTRAINT series_unique IF NOT EXISTS FOR (s:Series) 
REQUIRE (s.code,s.description) IS NODE KEY;
"""

statement_sm ="""
CREATE CONSTRAINT sm_unique IF NOT EXISTS FOR ( seriesmetadata:SeriesMetadata )
 REQUIRE (seriesmetadata.attributesCode, seriesmetadata.dimensionsCode,seriesmetadata.seriesCode) IS NODE KEY;
"""

statement_has_obs = """ 
CREATE CONSTRAINT has_obs_unique IF NOT EXISTS
FOR ()-[has_obs:HAS_OBSERVATION]-() REQUIRE (has_obs.attributesCode, has_obs.dimensionsCode,has_obs.seriesCode,has_obs.geoCode,has_obs.time) IS RELATIONSHIP KEY
"""

statement_so ="""CREATE CONSTRAINT source_name IF NOT EXISTS FOR (s:Source) 
REQUIRE s.name IS NODE KEY;
"""

# %% [markdown]
# > Property types

# %%
## Goal
statement_goal_code = """ 
CREATE CONSTRAINT goal_type_code IF NOT EXISTS
FOR (g:Goal) REQUIRE g.code :: STRING
"""
statement_goal_desc = """ 
CREATE CONSTRAINT goal_type_desc IF NOT EXISTS
FOR (g:Goal) REQUIRE g.description :: STRING
"""
statement_goal_title = """ 
CREATE CONSTRAINT goal_type_title IF NOT EXISTS
FOR (g:Goal) REQUIRE g.title :: STRING
"""

## Target
statement_target_code = """ 
CREATE CONSTRAINT target_type_code IF NOT EXISTS
FOR (t:Target) REQUIRE t.code :: STRING
"""
statement_target_desc = """ 
CREATE CONSTRAINT target_type_desc IF NOT EXISTS
FOR (t:Target) REQUIRE t.description :: STRING
"""
statement_target_title = """ 
CREATE CONSTRAINT target_type_title IF NOT EXISTS
FOR (t:Target) REQUIRE t.title :: STRING
"""

## Indicator
statement_indicator_code = """ 
CREATE CONSTRAINT indicator_type_code IF NOT EXISTS
FOR (i:Indicator)  REQUIRE i.code :: STRING
"""
statement_indicator_desc = """ 
CREATE CONSTRAINT indicator_type_desc IF NOT EXISTS
FOR (i:Indicator)  REQUIRE i.description :: STRING
"""

## Series
statement_series_code = """ 
CREATE CONSTRAINT series_type_code IF NOT EXISTS
FOR (s:Series) REQUIRE s.code :: STRING
"""
statement_series_desc = """ 
CREATE CONSTRAINT series_type_desc IF NOT EXISTS
FOR (s:Series)  REQUIRE s.description :: STRING
"""
statement_series_provider = """ 
CREATE CONSTRAINT series_type_desc IF NOT EXISTS
FOR (s:Series)  REQUIRE s.dataProviderURL :: STRING
"""

## SeriesMetadata

statement_sm_atcode = """ 
CREATE CONSTRAINT sm_type_attcode IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.attributesCode :: STRING
"""

statement_sm_dimcode = """ 
CREATE CONSTRAINT sm_type_dimcode IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.dimensionsCode :: STRING
"""
statement_sm_dimdesc= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.dimensionsDescription :: STRING
"""
statement_sm_attdesc= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.attributesDescription :: STRING
"""
statement_sm_seriesCode= """ 
CREATE CONSTRAINT sm_type_dimdesc IF NOT EXISTS
FOR (sm:SeriesMetadata) REQUIRE sm.seriesCode :: STRING
"""

### Observation
statement_obs_value = """ 
CREATE CONSTRAINT obs_type_value IF NOT EXISTS
FOR (o:Observation) REQUIRE o.value :: FLOAT
"""
statement_obs_time = """ 
CREATE CONSTRAINT obs_type_date IF NOT EXISTS
FOR (o:Observation) REQUIRE o.time :: DATE
"""

### Source
statement_so_name = """ 
CREATE CONSTRAINT so_type_name IF NOT EXISTS
FOR (so:Source) REQUIRE so.name :: STRING
"""

# %%
statements = [statement_goal,statement_goal_code,statement_goal_desc,statement_goal_title,
  statement_indicator,statement_indicator_code,statement_indicator_desc,
  statement_obs_time,statement_obs_value,
  statement_series,statement_series_code,statement_series_desc,statement_series_provider,
  statement_sm,statement_sm_atcode,statement_sm_attdesc,statement_sm_dimcode,statement_sm_dimdesc,statement_sm_seriesCode,
  statement_so,statement_so_name,
  statement_target,statement_target_code,statement_target_desc,statement_target_title,statement_has_obs]

with driver.session() as session:
    for statement in statements:
        session.execute_write(create_constraint, statement)

# %%
def cypher_run(tx,statement):
    tx.run(statement)

def cypher_run_params(tx,statement, params):
    tx.run(statement,parameters={"parameters":params})

# %% [markdown]
# Goals, Targets, Series, Indicators were retrieved from the United Nations SDG API and with the help of the APOC Neo4j’s standard library were introduced into the SustainGraph

# %% [markdown]
# ### Goals

# %%
statement_goals = """
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Goal/List?includechildren=false")
    YIELD value
    UNWIND value AS goal
    MERGE (g:Goal {code: toString(goal.code)})
    SET g.title = toString(goal.title)
    SET g.description = toString(goal.description)
    RETURN COUNT(DISTINCT g)
"""
with driver.session() as session:
    session.execute_write(cypher_run, statement = statement_goals)

# %% [markdown]
# ### Targets per Goal

# %%
statement_targets = """
    MATCH (g:Goal)
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Goal/"+g.code+"/Target/List?includechildren=true")
    YIELD value
    UNWIND value.targets AS target
    MERGE (t:Target {code: toString(target.code)})
    SET t.title = toString(target.title)
    SET t.description = toString(target.description)
    MERGE (t)<-[:HAS_TARGET]-(g)
"""
with driver.session() as session:
    session.execute_write(cypher_run, statement = statement_targets)

# %% [markdown]
# ### Indicators per Target

# %%
statement_ind = """
    MATCH (t:Target) 
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Target/"+t.code+"/Indicator/List?includechildren=true")
    YIELD value
    UNWIND value.indicators AS indicator
    MERGE (i:Indicator {code: toString(indicator.code)})
    SET i.description = toString(indicator.description)
    MERGE (s:Source{name:'UN_SDG'})
    MERGE (t)-[:HAS_INDICATOR]->(i)-[:COMES_FROM]->(s)
"""
with driver.session() as session:
    session.execute_write(cypher_run, statement = statement_ind)

# %% [markdown]
# ### Series per Indicator

# %%
statement_series = """
    MATCH (i:Indicator)-[:COMES_FROM]-(:Source{name:'UN_SDG'})
    CALL apoc.load.json("https://unstats.un.org/SDGAPI/v1/sdg/Indicator/"+i.code+"/Series/List")
    YIELD value
    UNWIND value.series AS series
    MERGE (s:Series {code: toString(series.code)})
    ON CREATE SET s.description = toString(series.description),
      s.dataProviderURL = 'https://unstats.un.org/sdgapi/swagger/'
    MERGE (i)-[:HAS_SERIES]->(s)
"""
with driver.session() as session:
    session.execute_write(cypher_run, statement = statement_series)

# %% [markdown]
# > Check cypher queries

# %%
records, summary, keys = driver.execute_query("""\
       MATCH (n:Goal) RETURN count(distinct n) as goals
        """,routing_="r")
print("{nodes_created} Goals in {time} ms.".format(
    nodes_created=records[0]['goals'],
    time=summary.result_available_after
))

records, summary, keys = driver.execute_query("""\
       MATCH (n:Target) RETURN count(distinct n) as targets
        """,routing_="r")
print("{nodes_created} Targets in {time} ms.".format(
    nodes_created=records[0]['targets'],
    time=summary.result_available_after
))

records, summary, keys = driver.execute_query("""\
       MATCH (n:Indicator) RETURN count(distinct n) as ind
        """,routing_="r")
print("{nodes_created} UN Indicators in {time} ms.".format(
    nodes_created=records[0]['ind'],
    time=summary.result_available_after
))

records, summary, keys = driver.execute_query("""\
       MATCH (n:Series) RETURN count(distinct n) as series
        """,routing_="r")
print("{nodes_created} UN Series in {time} ms.".format(
    nodes_created=records[0]['series'],
    time=summary.result_available_after
))
# Out:
# 17 Goals in 1 ms.
# 169 Targets in 0 ms.
# 248 UN Indicators in 0 ms.
# 692 UN Series in 0 ms.

# %% [markdown]
# ### Observations per Series

# %% [markdown]
# Each UN Series code has multiple observations for each GeoArea, for different time periods and also for different attributes and dimensions

# %%
def goal_series(tx,statement, goal):
    result = tx.run(statement,goal=goal)
    return result.data()[0]['s_codes']

# %%
# Get all series per goal and store them in a dictionary
series_per_goal ={}
statement = """
    MATCH (:Goal{code:$goal})-[:HAS_TARGET]->(:Target)-[:HAS_INDICATOR]->(:Indicator)-[:HAS_SERIES]->(s:Series)
    WITH COLLECT(DISTINCT s.code) as s_codes
    RETURN s_codes
    """
with driver.session() as session:
    for i in range(1,18):
        series_per_goal[str(i)] = session.execute_read(goal_series, statement = statement, goal = str(i))
        

# Function for mapping the code of an attribute or a dimension with its description (We dont consider NaN values)
def metadata_mapping( metadata) :
    mapping = {}
    for m in metadata:
        for  c in m["codes"]:
            mapping[c["code"]] = c["description"]
    return mapping

# %% [markdown]
# Collect data (observation per Series) only for European countries and countries of the European Union. <p>
# Note: Cyprus belongs to the European Union, but does not belong geographically to Europe.

# %%
def areas_codes(tx,statement):
    result = tx.run(statement)
    # print(result.data()[0]['geocodes'])
    return result.data()[0]['geocodes']

# Collect the available GeoArea codes of Europe in the SustainGraph
statement_areas = """
    MATCH (r:Region{name:'Europe'})-[:HAS_SUBREGION]->(sr:SubRegion)-[:HAS_AREA]->(a:Area)
    MATCH (eu:EuropeanUnion)<-[:BELONGS_TO]-(eua:Area)
    WITH COLLECT(DISTINCT a.M49code)+COLLECT(DISTINCT eua.M49code) as geocodes
    UNWIND geocodes as codes
    RETURN COLLECT(DISTINCT codes) as geocodes
    """

with driver.session() as session:
    geocodes = session.execute_read(areas_codes,statement_areas)

# %%
def create_params(series_code, geoAreas):
    return {
        'seriesCode':series_code,
        'areaCode': geoAreas # list of geoarea codes in M49
    }
def create_params_pages(series_code, geoAreas, pageSize):
    return {
        'seriesCode':series_code,
        'areaCode': geoAreas, #list of integers M49 codes
        'pageSize': pageSize
    }

headers = {
    'Accept': 'application/json'
}

#Function to collect the data per series code from the API
async def get_observations(session,series_code, geoAreas):
    async with session.get("https://unstats.un.org/sdgapi/v1/sdg/Series/Data", 
                           params = create_params(series_code,geoAreas),
                            headers = headers
                        ) as response:
        result = await response.json()
        print('Total elements of %s: %s in %s pages'%(series_code,result['totalElements'], result['totalPages']))
        exceptions = 0 
        obs = 0 
        params = []
        
        async with session.get("https://unstats.un.org/sdgapi/v1/sdg/Series/Data",
                                params = create_params_pages(series_code,geoAreas,str(result['totalElements'])),
                                headers = headers
                            ) as response:
            result = await response.json()
            attributes = metadata_mapping( result['attributes'])
            dimensions = metadata_mapping( result['dimensions'])
            data = result['data']
            for observation in data :
                if (observation['value']!='NaN'):
                    obs +=1
                    attributes_code_string = '|'.join(list( observation['attributes'].values()))
                    attr_description = []
                    for a in list( observation['attributes'].values()):
                        attr_description.append(attributes[a])
                    attributes_description_string = '|'.join(attr_description)

                    dimension_code_string = '|'.join(list( observation['dimensions'].values()))
                    dim_description = []
                    for d in list( observation['dimensions'].values()):
                        dim_description.append(dimensions[d])
                    dimension_description_string = '|'.join(dim_description)
                    
                    if (observation['valueType'] != "Float"):
                        #print ("Series: %s value" %observation["series"] )
                        #print(observation['value'])
                        exceptions +=1
                        if observation['value'][0] != '<' and observation['value'][0] != '>' :
                            print ("Series: %s value" %observation["series"] )
                            print(observation['value'])
                            continue
                        else:
                            value = observation['value'][1:]
                    else:
                        value = observation['value']
                        

                    params_dict={
                            'geo':str(observation['geoAreaCode']),
                            'year':str(int(observation['timePeriodStart'])),
                            'value':float(value),
                            'att_desc': attributes_description_string,
                            'att_codes': attributes_code_string,
                            'dim_desc': dimension_description_string,
                            'dim_codes': dimension_code_string,
                            's_code':observation['series']
                        }
                    params.append(params_dict)  
        print("Observations  %s %d" %(series_code,obs))
        if (exceptions>0):
            print("Exceptions %s %d" %(series_code,exceptions))
        
        return params #list of dictionaries per series code

# %% [markdown]
# ### Collect observation data from the API (optional)

# %% [markdown]
# Collect all the data from the API per goal (defining the parameter "goal") and
# store them in a json file in the folder "UNSDGobservations".
# For each goal we make asynchronous requests to collect the data of all its series

# %%
for goal in range(1,18):
    st = time.time()
    print("Goal", str(goal))
    async with aiohttp.ClientSession() as session: 
        tasks =[]
        for series_code in  series_per_goal[str(goal)]:
            tasks. append(asyncio.ensure_future(get_observations(session, series_code, geocodes )))
        params = await asyncio.gather(*tasks)
        
        et = time.time()
        elapsed_time = et - st # get the execution time
        print('Collect data :', elapsed_time/60, 'minutes')
        #Create the params.json file if not already created 
        filename = "data/2.UN_observations/observations"+str(goal)+".json"
        with open(filename,"w") as outfile:
            json.dump(params, outfile)
        print(filename, " created")
# Out:
# Goal 1
# 200
# {"size":25,"totalElements":0,"totalPages":0,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Observation Status","codes":[{"code":"A","description":"Normal value","sdmx":"A"},{"code":"B","description":"Time series break","sdmx":"B"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Age","codes":[{"code":"<15Y","description":"under 15 years old","sdmx":"Y0T14"},{"code":"<18Y","description":"under 18 years old","sdmx":"Y0T17"},{"code":"<10Y","description":"under 10 years old","sdmx":"Y0T9"},{"code":"<16Y","description":"under 16 years old","sdmx":"Y0T15"}]},{"id":"Location","codes":[{"code":"RURAL","description":"Rural","sdmx":"R"},{"code":"ALLAREA","description":"All areas","sdmx":"_T"},{"code":"URBAN","description":"Urban","sdmx":"U"}]},{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]},{"id":"Sex","codes":[{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"}]}],"data":[]}
# Total elements of SD_MDP_CSMP: 0 in 0 pages
# 200
# {"size":25,"totalElements":0,"totalPages":0,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Observation Status","codes":[{"code":"A","description":"Normal value","sdmx":"A"},{"code":"B","description":"Time series break","sdmx":"B"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Age","codes":[{"code":"ALLAGE","description":"All age ranges or no breaks by age","sdmx":"_T"}]},{"id":"Location","codes":[{"code":"RURAL","description":"Rural","sdmx":"R"},{"code":"ALLAREA","description":"All areas","sdmx":"_T"},{"code":"URBAN","description":"Urban","sdmx":"U"}]},{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]},{"id":"Sex","codes":[{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"}]}],"data":[]}
# Total elements of SD_MDP_ANDI: 0 in 0 pages
# 200
# {"size":25,"totalElements":298,"totalPages":12,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"UnitMultiplier","codes":[{"code":"UNIT","description":"Units","sdmx":"0"}]},{"id":"Units","codes":[{"code":"CU_USD_M","description":"Millions of current United States dollars","sdmx":"USD"},{"code":"CU_USD","description":"USD","sdmx":"USD"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]}],"data":[{"goal":["1"],"target":["1.5"],"indicator":["1.5.2"],"series":"VC_DSR_AGLH","seriesDescription":"Direct agriculture loss attributed to disasters (current United States dollars)","seriesCount":"650","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2018.0,"value":"17004.9456","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: The data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) DesInventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"CU_USD"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.2"],"series":"VC_DSR_AGLH","seriesDescription":"Direct agriculture loss attributed to disasters (current United States dollars)","seriesCount":"650","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2022.0,"value":"266495.36899","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: The data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) DesInventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"E","Units":"CU_USD"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.2"],"series":"VC_DSR_AGLH","seriesDescription":"Direct agriculture loss attributed to disasters (current United States dollars)","seriesCount":"650","geoAreaCode":"40","geoAreaName":"Austria","timePeriodStart":2018.0,"value":"54180382.828","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: The data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) DesInventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"CU_USD"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.2"],"series":"VC_DSR_AGLH","seriesDescription":"Direct agriculture loss attributed to disasters (current United States dollars)","seriesCount":"650","geoAreaCode":"40","geoAreaName":"Austria","timePeriodStart":2019.0,"value":"61866781.9","valueType":"Float","time_detail":null,"timeC ...
# Total elements of VC_DSR_AGLH: 298 in 12 pages
# 200
# 200
# {"size":25,"totalElements":4,"totalPages":1,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"},{"code":"R","description":"Regional","sdmx":"R"}]},{"id":"Sex","codes":[{"code":"_X","description":"Not available","sdmx":"_X"},{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"},{"code":"_N","description":"No response","sdmx":"_N"},{"code":"_O","description":"Other","sdmx":"_O"},{"code":"_U","description":"Unknown","sdmx":"_U"}]}],"data":[{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSTR","seriesDescription":"Proportion of people with secure tenure rights to land out of total adult population, by sex (%)","seriesCount":"44","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2018.0,"value":"65.2","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Demographic and Health Survey","geoInfoUrl":null,"footnotes":["Total population is restricted to household head and wife due to data limitations."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSTR","seriesDescription":"Proportion of people with secure tenure rights to land out of total adult population, by sex (%)","seriesCount":"44","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2018.0,"value":"70.0","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Demographic and Health Survey","geoInfoUrl":null,"footnotes":["Total population is restricted to household head and wife due to data limitations."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"FEMALE","Reporting Type":"G"}},{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSTR","seriesDescription":"Proportion of people with secure tenure rights to land out of total adult population, by sex (%)","seriesCount":"44","geoAreaCode":"56","geoAreaName":"Belgium","timePeriodStart":2011.0,"value":"99.0","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Census data","geoInfoUrl":null,"footnotes":["Total population restricted to household head and wife due to data limitations. Documented ownership and rental used to produce the estimates."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSTR","seriesDescription":"Proportion of people with secure tenure rights to land out of total adult population, by sex (%)","seriesCount":"44","geoAreaCode":"528","geoAreaName":"Netherlands (Kingdom of the)","timePeriodStart":2011.0,"value":"96.8","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Census data","geoInfoUrl":null,"footnotes":["Total population restricted to household head and wife due to data limitations. Documented ownership and rental used to produce the estimates."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}}]}
# Total elements of SP_LGL_LNDSTR: 4 in 1 pages
# 200
# 200
# {"size":25,"totalElements":142,"totalPages":6,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Observation Status","codes":[{"code":"A","description":"Normal value","sdmx":"A"},{"code":"U","description":"Low reliability","sdmx":"U"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]},{"id":"Sex","codes":[{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"}]}],"data":[{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_WKINJRY","seriesDescription":"[ILO] Proportion of employed population covered in the event of work injury, by sex (%)","seriesCount":"679","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"34","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":["Estimated based on legal coverage"],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_WKINJRY","seriesDescription":"[ILO] Proportion of employed population covered in the event of work injury, by sex (%)","seriesCount":"679","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2019.0,"value":"34","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":["Estimated based on legal coverage"],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_WKINJRY","seriesDescription":"[ILO] Proportion of employed population covered in the event of work injury, by sex (%)","seriesCount":"679","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2021.0,"value":"40.7","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":["Estimated based on legal coverage"],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_WKINJRY","seriesDescription":"[ILO] Proportion of employed population covered in the event of work injury, by sex (%)","seriesCount":"679","geoAreaCode":"20","geoAreaName":"Andorra","timePeriodStart":2020.0,"value":"100","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_WKINJRY","seriesDescription":"[ILO] Proportion of employed population covered in the event of work injur ...
# Total elements of SI_COV_WKINJRY: 142 in 6 pages
# {"size":25,"totalElements":486,"totalPages":20,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Age","codes":[{"code":"<1M","description":"under 1 month old","sdmx":"M0"},{"code":"<1Y","description":"under 1 year old","sdmx":"Y0"},{"code":"<5Y","description":"under 5 years old","sdmx":"Y0T4"},{"code":"<15Y","description":"under 15 years old","sdmx":"Y0T14"},{"code":"<18Y","description":"under 18 years old","sdmx":"Y0T17"},{"code":"ALLAGE","description":"All age ranges or no breaks by age","sdmx":"_T"},{"code":"1-14","description":"1 to 14 years old","sdmx":"Y1T14"},{"code":"1-17","description":"1 to 17 years old","sdmx":"Y1T17"},{"code":"5-14","description":"5 to 14 years old","sdmx":"Y5T14"},{"code":"5-17","description":"5 to 17 years old","sdmx":"Y5T17"},{"code":"5+","description":"5 years old and over","sdmx":"Y_GE5"},{"code":"6-14","description":"6 to 14 years old","sdmx":"Y6T14"},{"code":"6-17","description":"6 to 17 years old","sdmx":"Y6T17"},{"code":"6+","description":"6 years old and over","sdmx":"Y_GE6"},{"code":"7-14","description":"7 to 14 years old","sdmx":"Y7T14"},{"code":"7-17","description":"7 to 17 years old","sdmx":"Y7T17"},{"code":"7+","description":"7 years old and over","sdmx":"Y_GE7"},{"code":"10-14","description":"10 to 14 years old","sdmx":"Y10T14"},{"code":"10-17","description":"10 to 17 years old","sdmx":"Y10T17"},{"code":"10-24","description":"10 to 24 years old","sdmx":"Y10T24"},{"code":"10-74","description":"10 to 74 years old","sdmx":"Y10T74"},{"code":"10+","description":"10 years old and over","sdmx":"Y_GE10"},{"code":"12-14","description":"12 to 14 years old","sdmx":"Y12T14"},{"code":"12-17","description":"12 to 17 years old","sdmx":"Y12T17"},{"code":"12-30","description":"12 to 30 years old","sdmx":"Y12T30"},{"code":"12+","description":"12 years old and over","sdmx":"Y_GE12"},{"code":"14-24","description":"14 to 24 years old","sdmx":"Y14T24"},{"code":"14-28","description":"14 to 28 years old","sdmx":"Y14T28"},{"code":"14-29","description":"14 to 29 years old","sdmx":"Y14T29"},{"code":"14+","description":"14 years old and over","sdmx":"Y_GE14"},{"code":"15-17","description":"15 to 17 years old","sdmx":"Y15T17"},{"code":"15-19","description":"15 to 19 years old","sdmx":"Y15T19"},{"code":"15-24","description":"15 to 24 years old","sdmx":"Y15T24"},{"code":"15-29","description":"15 to 29 years old","sdmx":"Y15T29"},{"code":"15-44","description":"15 to 44 years old","sdmx":"Y15T44"},{"code":"15-49","description":"15 to 49 years old","sdmx":"Y15T49"},{"code":"15-60","description":"15 to 60 years old","sdmx":"Y15T60"},{"code":"15-64","description":"15 to 64 years old","sdmx":"Y15T64"},{"code":"15-65","description":"15 to 65 years old","sdmx":"Y15T65"},{"code":"15-70","description":"15 to 70 years old","sdmx":"Y15T70"},{"code":"15-72","description":"15 to 72 years old","sdmx":"Y15T72"},{"code":"15-74","description":"15 to 74 years old","sdmx":"Y15T74"},{"code":"15-80","description":"15 to 80 years old","sdmx":"Y15T80"},{"code":"15-84","description":"15 to 84 years old","sdmx":"Y15T84"},{"code":"15+","description":"15 years old and over","sdmx":"Y_GE15"},{"code":"16-24","description":"16 to 24 years old","sdmx":"Y16T24"},{"code":"16-65","description":"16 to 65 years old","sdmx":"Y16T65"},{"code":"16-74","description":"16 to 74 years old","sdmx":"Y16T74"},{"code":"16+","description":"16 years old and over","sdmx":"Y_GE16"},{"code":"18-27","description":"18 to 27 years old","sdmx":"Y18T27"},{"code":"18-29","description":"18 to 29 years old","sdmx":"Y18T29"},{"code":"18-35","description":"18 to 35 years old","sdmx":"Y18T35"},{"code":"18-44","description":"18 to 44 years old","sdmx":"Y18T44"},{"code":"18+","description":"18 years old and over","sdmx":"Y_GE18"},{"code":"19-65","descript ...
# Total elements of SI_POV_NAHC: 486 in 20 pages
# {"size":25,"totalElements":84,"totalPages":4,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Quantile","codes":[{"code":"Q1","description":"Quantile 1 (poorest)","sdmx":"Q1"},{"code":"Q2","description":"Quantile 2","sdmx":"Q2"},{"code":"Q3","description":"Quantile 3","sdmx":"Q3"},{"code":"Q4","description":"Quantile 4","sdmx":"Q4"},{"code":"Q5","description":"Quantile 5 (richest)","sdmx":"Q5"},{"code":"B40","description":"Bottom 40%","sdmx":"B40"},{"code":"R60","description":"Richest 60%","sdmx":"R60"},{"code":"_T","description":"Total (national average) or no breakdown","sdmx":"_T"}]},{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]}],"data":[{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_LMKT","seriesDescription":"[World Bank] Proportion of population covered by labour market programs (%)","seriesCount":"461","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"7.86586","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"Q1"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_LMKT","seriesDescription":"[World Bank] Proportion of population covered by labour market programs (%)","seriesCount":"461","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"6.04202","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"_T"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_LMKT","seriesDescription":"[World Bank] Proportion of population covered by labour market programs (%)","seriesCount":"461","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2012.0,"value":"14.22281","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"_T"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_LMKT","seriesDescription":"[World Bank] Proportion of population covered by labour market programs (%)","seriesCount":"461","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2012.0,"value":"17.03102","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (dat ...
# Total elements of SI_COV_LMKT: 84 in 4 pages
# 200
# {"size":25,"totalElements":4699,"totalPages":188,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Age","codes":[{"code":"<1M","description":"under 1 month old","sdmx":"M0"},{"code":"<1Y","description":"under 1 year old","sdmx":"Y0"},{"code":"<5Y","description":"under 5 years old","sdmx":"Y0T4"},{"code":"<15Y","description":"under 15 years old","sdmx":"Y0T14"},{"code":"<18Y","description":"under 18 years old","sdmx":"Y0T17"},{"code":"ALLAGE","description":"All age ranges or no breaks by age","sdmx":"_T"},{"code":"1-14","description":"1 to 14 years old","sdmx":"Y1T14"},{"code":"1-17","description":"1 to 17 years old","sdmx":"Y1T17"},{"code":"5-14","description":"5 to 14 years old","sdmx":"Y5T14"},{"code":"5-17","description":"5 to 17 years old","sdmx":"Y5T17"},{"code":"5+","description":"5 years old and over","sdmx":"Y_GE5"},{"code":"6-14","description":"6 to 14 years old","sdmx":"Y6T14"},{"code":"6-17","description":"6 to 17 years old","sdmx":"Y6T17"},{"code":"6+","description":"6 years old and over","sdmx":"Y_GE6"},{"code":"7-14","description":"7 to 14 years old","sdmx":"Y7T14"},{"code":"7-17","description":"7 to 17 years old","sdmx":"Y7T17"},{"code":"7+","description":"7 years old and over","sdmx":"Y_GE7"},{"code":"10-14","description":"10 to 14 years old","sdmx":"Y10T14"},{"code":"10-17","description":"10 to 17 years old","sdmx":"Y10T17"},{"code":"10-24","description":"10 to 24 years old","sdmx":"Y10T24"},{"code":"10-74","description":"10 to 74 years old","sdmx":"Y10T74"},{"code":"10+","description":"10 years old and over","sdmx":"Y_GE10"},{"code":"12-14","description":"12 to 14 years old","sdmx":"Y12T14"},{"code":"12-17","description":"12 to 17 years old","sdmx":"Y12T17"},{"code":"12-30","description":"12 to 30 years old","sdmx":"Y12T30"},{"code":"12+","description":"12 years old and over","sdmx":"Y_GE12"},{"code":"14-24","description":"14 to 24 years old","sdmx":"Y14T24"},{"code":"14-28","description":"14 to 28 years old","sdmx":"Y14T28"},{"code":"14-29","description":"14 to 29 years old","sdmx":"Y14T29"},{"code":"14+","description":"14 years old and over","sdmx":"Y_GE14"},{"code":"15-17","description":"15 to 17 years old","sdmx":"Y15T17"},{"code":"15-19","description":"15 to 19 years old","sdmx":"Y15T19"},{"code":"15-24","description":"15 to 24 years old","sdmx":"Y15T24"},{"code":"15-29","description":"15 to 29 years old","sdmx":"Y15T29"},{"code":"15-44","description":"15 to 44 years old","sdmx":"Y15T44"},{"code":"15-49","description":"15 to 49 years old","sdmx":"Y15T49"},{"code":"15-60","description":"15 to 60 years old","sdmx":"Y15T60"},{"code":"15-64","description":"15 to 64 years old","sdmx":"Y15T64"},{"code":"15-65","description":"15 to 65 years old","sdmx":"Y15T65"},{"code":"15-70","description":"15 to 70 years old","sdmx":"Y15T70"},{"code":"15-72","description":"15 to 72 years old","sdmx":"Y15T72"},{"code":"15-74","description":"15 to 74 years old","sdmx":"Y15T74"},{"code":"15-80","description":"15 to 80 years old","sdmx":"Y15T80"},{"code":"15-84","description":"15 to 84 years old","sdmx":"Y15T84"},{"code":"15+","description":"15 years old and over","sdmx":"Y_GE15"},{"code":"16-24","description":"16 to 24 years old","sdmx":"Y16T24"},{"code":"16-65","description":"16 to 65 years old","sdmx":"Y16T65"},{"code":"16-74","description":"16 to 74 years old","sdmx":"Y16T74"},{"code":"16+","description":"16 years old and over","sdmx":"Y_GE16"},{"code":"18-27","description":"18 to 27 years old","sdmx":"Y18T27"},{"co ...
# Total elements of SI_POV_DAY1: 4699 in 188 pages
# 200
# {"size":25,"totalElements":56,"totalPages":3,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Observation Status","codes":[{"code":"A","description":"Normal value","sdmx":"A"},{"code":"U","description":"Low reliability","sdmx":"U"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]},{"id":"Sex","codes":[{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"}]}],"data":[{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_POOR","seriesDescription":"[ILO] Proportion of poor population receiving social assistance cash benefit, by sex (%)","seriesCount":"292","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2021.0,"value":"100","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_POOR","seriesDescription":"[ILO] Proportion of poor population receiving social assistance cash benefit, by sex (%)","seriesCount":"292","geoAreaCode":"20","geoAreaName":"Andorra","timePeriodStart":2022.0,"value":"10.8","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_POOR","seriesDescription":"[ILO] Proportion of poor population receiving social assistance cash benefit, by sex (%)","seriesCount":"292","geoAreaCode":"40","geoAreaName":"Austria","timePeriodStart":2016.0,"value":"100","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_POOR","seriesDescription":"[ILO] Proportion of poor population receiving social assistance cash benefit, by sex (%)","seriesCount":"292","geoAreaCode":"40","geoAreaName":"Austria","timePeriodStart":2021.0,"value":"100","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ILO estimates based on country data compled through the ILO Social Security Inquiry (SSI)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"E","Units":"PERCENT","Observation Status":"A"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_POOR","seriesDescription":"[ILO] Proportion of poor population receiving social assistance cash benefit, by sex (%)","seriesCount":"292","geoAreaCode":"56","geoAreaName":"Belgium","timePeriodStart":2016.0,"va ...
# Total elements of SI_COV_POOR: 56 in 3 pages
# 200
# {"size":25,"totalElements":3,"totalPages":1,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"},{"code":"R","description":"Regional","sdmx":"R"}]},{"id":"Sex","codes":[{"code":"_X","description":"Not available","sdmx":"_X"},{"code":"FEMALE","description":"Female","sdmx":"F"},{"code":"MALE","description":"Male","sdmx":"M"},{"code":"BOTHSEX","description":"Both sexes","sdmx":"_T"},{"code":"_N","description":"No response","sdmx":"_N"},{"code":"_O","description":"Other","sdmx":"_O"},{"code":"_U","description":"Unknown","sdmx":"_U"}]}],"data":[{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSEC","seriesDescription":"Proportion of people who perceive their rights to land as secure out of total adult population, by sex (%)","seriesCount":"22","geoAreaCode":"56","geoAreaName":"Belgium","timePeriodStart":2011.0,"value":"93.9","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Census & Administrative Data.","geoInfoUrl":null,"footnotes":["Total population is restricted to household head and wife of rural population due to data limitations."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSEC","seriesDescription":"Proportion of people who perceive their rights to land as secure out of total adult population, by sex (%)","seriesCount":"22","geoAreaCode":"528","geoAreaName":"Netherlands (Kingdom of the)","timePeriodStart":2011.0,"value":"96.8","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Census & Administrative Data.","geoInfoUrl":null,"footnotes":["Total population is restricted to household head and wife of rural population due to data limitations."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}},{"goal":["1"],"target":["1.4"],"indicator":["1.4.2"],"series":"SP_LGL_LNDSEC","seriesDescription":"Proportion of people who perceive their rights to land as secure out of total adult population, by sex (%)","seriesCount":"22","geoAreaCode":"752","geoAreaName":"Sweden","timePeriodStart":2011.0,"value":"96.9","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Census & Administrative Data.","geoInfoUrl":null,"footnotes":["Total population is restricted to household head and wife of rural population due to data limitations."],"attributes":{"Nature":"E","Units":"PERCENT"},"dimensions":{"Sex":"BOTHSEX","Reporting Type":"G"}}]}
# Total elements of SP_LGL_LNDSEC: 3 in 1 pages
# 200
# {"size":25,"totalElements":140,"totalPages":6,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Quantile","codes":[{"code":"Q1","description":"Quantile 1 (poorest)","sdmx":"Q1"},{"code":"Q2","description":"Quantile 2","sdmx":"Q2"},{"code":"Q3","description":"Quantile 3","sdmx":"Q3"},{"code":"Q4","description":"Quantile 4","sdmx":"Q4"},{"code":"Q5","description":"Quantile 5 (richest)","sdmx":"Q5"},{"code":"B40","description":"Bottom 40%","sdmx":"B40"},{"code":"R60","description":"Richest 60%","sdmx":"R60"},{"code":"_T","description":"Total (national average) or no breakdown","sdmx":"_T"}]},{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]}],"data":[{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_SOCINS","seriesDescription":"[World Bank] Proportion of population covered by social insurance programs (%)","seriesCount":"910","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"45.93881","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"_T"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_SOCINS","seriesDescription":"[World Bank] Proportion of population covered by social insurance programs (%)","seriesCount":"910","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"48.43734","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"Q1"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_SOCINS","seriesDescription":"[World Bank] Proportion of population covered by social insurance programs (%)","seriesCount":"910","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2012.0,"value":"36.25506","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"CA","Units":"PERCENT"},"dimensions":{"Reporting Type":"G","Quantile":"_T"}},{"goal":["1"],"target":["1.3"],"indicator":["1.3.1"],"series":"SI_COV_SOCINS","seriesDescription":"[World Bank] Proportion of population covered by social insurance programs (%)","seriesCount":"910","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2012.0,"value":"38.22971","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative  ...
# Total elements of SI_COV_SOCINS: 140 in 6 pages
# 200
# {"size":25,"totalElements":978,"totalPages":40,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"NUMBER","description":"Number","sdmx":"NUMBER"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]}],"data":[{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_MORT","seriesDescription":"Number of deaths due to disaster (number)","seriesCount":"1810","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2005.0,"value":"7","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_MORT","seriesDescription":"Number of deaths due to disaster (number)","seriesCount":"1810","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2006.0,"value":"2","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_MORT","seriesDescription":"Number of deaths due to disaster (number)","seriesCount":"1810","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2007.0,"value":"2","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_MORT","seriesDescription":"Number of deaths due to disaster (number)","seriesCount":"1810","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"16","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinv ...
# Total elements of VC_DSR_MORT: 978 in 40 pages
# 200
# {"size":25,"totalElements":588,"totalPages":24,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"NUMBER","description":"Number","sdmx":"NUMBER"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"}]}],"data":[{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_PDYN","seriesDescription":"Number of people whose destroyed dwellings were attributed to disasters (number)","seriesCount":"1316","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2005.0,"value":"632","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_PDYN","seriesDescription":"Number of people whose destroyed dwellings were attributed to disasters (number)","seriesCount":"1316","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2006.0,"value":"188","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_PDYN","seriesDescription":"Number of people whose destroyed dwellings were attributed to disasters (number)","seriesCount":"1316","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2007.0,"value":"104","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being submitted by UNDRR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not followed an official validation process and may be subject to revision at a later date."],"attributes":{"Nature":"C","Units":"NUMBER"},"dimensions":{"Reporting Type":"G"}},{"goal":["1"],"target":["1.5"],"indicator":["1.5.1"],"series":"VC_DSR_PDYN","seriesDescription":"Number of people whose destroyed dwellings were attributed to disasters (number)","seriesCount":"1316","geoAreaCode":"8","geoAreaName":"Albania","timePeriodStart":2008.0,"value":"184","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"United Nations Office for Disaster Risk Reduction (2024)","geoInfoUrl":null,"footnotes":["Disclaimer: the data being ...
# Total elements of VC_DSR_PDYN: 588 in 24 pages
# 200
# 200
# 200
# ...
# Total elements of SE_ADT_FUNS: 138 in 6 pages
# 200
# {"size":25,"totalElements":81,"totalPages":4,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"INDEX","description":"Index","sdmx":"IX"}]}],"dimensions":[{"id":"Reporting Type","codes":[{"code":"N","description":"National","sdmx":"N"},{"code":"G","description":"Global","sdmx":"G"},{"code":"R","description":"Regional","sdmx":"R"}]}],"data":[{"goal":["12"],"target":["12.8"],"indicator":["12.8.1"],"series":"SE_GCEDESD_CUR","seriesDescription":"Extent to which global citizenship education and education for sustainable development are mainstreamed in curricula","seriesCount":"59","geoAreaCode":"20","geoAreaName":"Andorra","timePeriodStart":2020.0,"value":"0.9375","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Country reports on the implementation of the UNESCO 1974 Recommendation concerning Education for International Understanding, Co-operation and Peace and Education relating to Human Rights and Fundamental Freedoms","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"C","Units":"INDEX"},"dimensions":{"Reporting Type":"G"}},{"goal":["12"],"target":["12.8"],"indicator":["12.8.1"],"series":"SE_GCEDESD_CUR","seriesDescription":"Extent to which global citizenship education and education for sustainable development are mainstreamed in curricula","seriesCount":"59","geoAreaCode":"56","geoAreaName":"Belgium","timePeriodStart":2020.0,"value":"0.875","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Country reports on the implementation of the UNESCO 1974 Recommendation concerning Education for International Understanding, Co-operation and Peace and Education relating to Human Rights and Fundamental Freedoms","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"C","Units":"INDEX"},"dimensions":{"Reporting Type":"G"}},{"goal":["12"],"target":["12.8"],"indicator":["12.8.1"],"series":"SE_GCEDESD_CUR","seriesDescription":"Extent to which global citizenship education and education for sustainable development are mainstreamed in curricula","seriesCount":"59","geoAreaCode":"100","geoAreaName":"Bulgaria","timePeriodStart":2020.0,"value":"0.64773","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Country reports on the implementation of the UNESCO 1974 Recommendation concerning Education for International Understanding, Co-operation and Peace and Education relating to Human Rights and Fundamental Freedoms","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"C","Units":"INDEX"},"dimensions":{"Reporting Type":"G"}},{"goal":["12"],"target":["12.8"],"indicator":["12.8.1"],"series":"SE_GCEDESD_CUR","seriesDescription":"Extent to which global citizenship education and education for sustainable development are mainstreamed in curricula","seriesCount":"59","geoAreaCode":"196","geoAreaName":"Cyprus","timePeriodStart":2020.0,"value":"0.92448","valueType":"Float","time_detail":null,"timeCoverage":null,"upperBound":null,"lowerBound":null,"basePeriod":null,"source":"Country reports on the implementation of the UNESCO 1974 Recommendation concerning Education for International Understanding, Co-operation and Peace and Education relating to Human Rights and Fundamental Freedoms","geoInfoUrl":null,"footnotes":[""],"attributes":{"Nature":"C","Units":"INDEX"},"dimensions":{"Reporting Type":"G"}},{"goal":["12"],"target":["12.8"],"indicator":["12.8.1"],"series":"SE_GCEDESD_CUR","seriesDescript ...
# Total elements of SE_GCEDESD_CUR: 81 in 4 pages
# 200
# {"size":25,"totalElements":63921,"totalPages":2557,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"PERCENT","description":"Percentage","sdmx":"PT"}]}],"dimensions":[{"id":"Age","codes":[{"code":"<1M","description":"under 1 month old","sdmx":"M0"},{"code":"<1Y","description":"under 1 year old","sdmx":"Y0"},{"code":"<5Y","description":"under 5 years old","sdmx":"Y0T4"},{"code":"<15Y","description":"under 15 years old","sdmx":"Y0T14"},{"code":"<18Y","description":"under 18 years old","sdmx":"Y0T17"},{"code":"ALLAGE","description":"All age ranges or no breaks by age","sdmx":"_T"},{"code":"1-14","description":"1 to 14 years old","sdmx":"Y1T14"},{"code":"1-17","description":"1 to 17 years old","sdmx":"Y1T17"},{"code":"5-14","description":"5 to 14 years old","sdmx":"Y5T14"},{"code":"5-17","description":"5 to 17 years old","sdmx":"Y5T17"},{"code":"5+","description":"5 years old and over","sdmx":"Y_GE5"},{"code":"6-14","description":"6 to 14 years old","sdmx":"Y6T14"},{"code":"6-17","description":"6 to 17 years old","sdmx":"Y6T17"},{"code":"6+","description":"6 years old and over","sdmx":"Y_GE6"},{"code":"7-14","description":"7 to 14 years old","sdmx":"Y7T14"},{"code":"7-17","description":"7 to 17 years old","sdmx":"Y7T17"},{"code":"7+","description":"7 years old and over","sdmx":"Y_GE7"},{"code":"10-14","description":"10 to 14 years old","sdmx":"Y10T14"},{"code":"10-17","description":"10 to 17 years old","sdmx":"Y10T17"},{"code":"10-24","description":"10 to 24 years old","sdmx":"Y10T24"},{"code":"10-74","description":"10 to 74 years old","sdmx":"Y10T74"},{"code":"10+","description":"10 years old and over","sdmx":"Y_GE10"},{"code":"12-14","description":"12 to 14 years old","sdmx":"Y12T14"},{"code":"12-17","description":"12 to 17 years old","sdmx":"Y12T17"},{"code":"12-30","description":"12 to 30 years old","sdmx":"Y12T30"},{"code":"12+","description":"12 years old and over","sdmx":"Y_GE12"},{"code":"14-24","description":"14 to 24 years old","sdmx":"Y14T24"},{"code":"14-28","description":"14 to 28 years old","sdmx":"Y14T28"},{"code":"14-29","description":"14 to 29 years old","sdmx":"Y14T29"},{"code":"14+","description":"14 years old and over","sdmx":"Y_GE14"},{"code":"15-17","description":"15 to 17 years old","sdmx":"Y15T17"},{"code":"15-19","description":"15 to 19 years old","sdmx":"Y15T19"},{"code":"15-24","description":"15 to 24 years old","sdmx":"Y15T24"},{"code":"15-29","description":"15 to 29 years old","sdmx":"Y15T29"},{"code":"15-44","description":"15 to 44 years old","sdmx":"Y15T44"},{"code":"15-49","description":"15 to 49 years old","sdmx":"Y15T49"},{"code":"15-60","description":"15 to 60 years old","sdmx":"Y15T60"},{"code":"15-64","description":"15 to 64 years old","sdmx":"Y15T64"},{"code":"15-65","description":"15 to 65 years old","sdmx":"Y15T65"},{"code":"15-70","description":"15 to 70 years old","sdmx":"Y15T70"},{"code":"15-72","description":"15 to 72 years old","sdmx":"Y15T72"},{"code":"15-74","description":"15 to 74 years old","sdmx":"Y15T74"},{"code":"15-80","description":"15 to 80 years old","sdmx":"Y15T80"},{"code":"15-84","description":"15 to 84 years old","sdmx":"Y15T84"},{"code":"15+","description":"15 years old and over","sdmx":"Y_GE15"},{"code":"16-24","description":"16 to 24 years old","sdmx":"Y16T24"},{"code":"16-65","description":"16 to 65 years old","sdmx":"Y16T65"},{"code":"16-74","description":"16 to 74 years old","sdmx":"Y16T74"},{"code":"16+","description":"16 years old and over","sdmx":"Y_GE16"},{"code":"18-27","description":"18 to 27 years old","sdmx":"Y18T27"},{" ...
# Total elements of SE_ADT_ACTS: 63921 in 2557 pages
# 200
# {"size":25,"totalElements":671,"totalPages":27,"pageNumber":1,"attributes":[{"id":"Nature","codes":[{"code":"C","description":"Country data","sdmx":"C"},{"code":"CA","description":"Country adjusted data","sdmx":"CA"},{"code":"E","description":"Estimated data","sdmx":"E"},{"code":"G","description":"Global monitoring data","sdmx":"G"},{"code":"M","description":"Modeled data","sdmx":"M"},{"code":"N","description":"Non-relevant","sdmx":"N"},{"code":"NA","description":"Data nature not available","sdmx":"_X"}]},{"id":"Units","codes":[{"code":"Ratio","description":"Ratio","sdmx":"RO"}]}],"dimensions":[{"id":"Education level","codes":[{"code":"ISCED11_0","description":"Early childhood education","sdmx":"ISCED11_0"},{"code":"ISCED11_01","description":"Early childhood educational development ","sdmx":"ISCED11_01"},{"code":"ISCED11_10","description":"Primary education","sdmx":"ISCED11_10"},{"code":"ISCED11_24","description":"Lower secondary general education","sdmx":"ISCED11_24"},{"code":"ISCED11_25","description":"Lower secondary vocational education","sdmx":"ISCED11_25"},{"code":"ISCED11_34","description":"Upper secondary general education","sdmx":"ISCED11_34"},{"code":"ISCED11_35","description":"Upper secondary vocational education","sdmx":"ISCED11_35"},{"code":"ISCED11_4","description":"Post-secondary non-tertiary education","sdmx":"ISCED11_4"},{"code":"ISCED11_44","description":"Post-secondary non-tertiary general education","sdmx":"ISCED11_44"},{"code":"ISCED11_45","description":"Post-secondary non-tertiary vocational education","sdmx":"ISCED11_45"},{"code":"ISCED11_5","description":"Short-cycle tertiary education","sdmx":"ISCED11_5"},{"code":"ISCED11_54","description":"Short-cycle tertiary general education","sdmx":"ISCED11_54"},{"code":"ISCED11_55","description":"Short-cycle tertiary vocational education","sdmx":"ISCED11_55"},{"code":"ISCED11_6","description":"Bachelor’s or equivalent level","sdmx":"ISCED11_6"},{"code":"ISCED11_7","description":"Master’s or equivalent level","sdmx":"ISCED11_7"},{"code":"ISCED11_8","description":"Doctoral or equivalent level","sdmx":"ISCED11_8"},{"code":"ISCED11_9","description":"Not elsewhere classified   ","sdmx":"ISCED11_9"},{"code":"ISCED11_99","description":"Not elsewhere classified ","sdmx":"ISCED11_99"},{"code":"ISCED11A_0","description":"Less than primary education","sdmx":"ISCED11A_0"},{"code":"ISCED11A_01","description":"Never attended an education programme / No schooling","sdmx":"ISCED11A_01"},{"code":"ISCED11A_02","description":"Some early childhood education","sdmx":"ISCED11A_02"},{"code":"ISCED11A_03","description":"Some primary education","sdmx":"ISCED11A_03"},{"code":"ISCED11A_1","description":"Primary education, sufficient for level completion","sdmx":"ISCED11A_1"},{"code":"ISCED11A_2","description":"Lower secondary education, sufficient for level completion","sdmx":"ISCED11A_2"},{"code":"ISCED11A_3","description":"Upper secondary education, sufficient for level completion","sdmx":"ISCED11A_3"},{"code":"ISCED11A_4","description":"Post-secondary non-tertiary education, sufficient for level completion","sdmx":"ISCED11A_4"},{"code":"ISCED11A_5","description":"Short-cycle tertiary education, sufficient for level completion","sdmx":"ISCED11A_5"},{"code":"ISCED11A_6","description":"Bachelor’s or equivalent level, sufficient for level completion","sdmx":"ISCED11A_6"},{"code":"ISCED11A_7","description":"Master’s or equivalent level, sufficient for level completion","sdmx":"ISCED11A_7"},{"code":"ISCED11A_8","description":"Doctoral or equivalent level, sufficient for level completion","sdmx":"ISCED11A_8"},{"code":"AGGA_01_02","description":"No primary schooling","sdmx":"AGGA_01_02"},{"code":"AGG_02T8","description":"Pre-primary to tertiary education","sdmx":"AGG_02T8"},{"code":"AGG_1_2","description":"Primary and lower secondary education (basic education)","sdmx":"AGG_1_2"},{"code":"AGG_1T3","description":"Primary and secondary education","sdmx":"AGG_1T3"},{"code":"AGG_5T8","description": ...
# Total elements of SE_TOT_SESPI: 671 in 27 pages
# Observations  SE_DEV_ONTRK 21
# Observations  SE_IMP_FPOF 44
# Observations  SE_TOT_SESPI_FS 46
# Observations  SE_GCEDESD_TED 81
# Observations  SE_GCEDESD_SAS 81
# Observations  SE_GCEDESD_CUR 81
# Observations  SE_GCEDESD_NEP 90
# Observations  SE_TOT_GPI_FS 46
# Observations  DC_TOF_SCHIPSL 141
# Observations  SE_ADT_FUNS 138
# Observations  SE_INF_DSBL 304
# Observations  SE_NAP_ACHI 586
# Observations  SE_GPI_TCAQ 649
# Observations  SE_TOT_SESPI 671
# Observations  SE_TOT_RUPI 511
# Observations  SE_LGP_ACHI 677
# Observations  SE_TOT_GPI 694
# Observations  SE_GPI_PTNPRE 786
# Observations  SE_AWP_CPRA 464
# Observations  SE_ACS_SANIT 1098
# Observations  SE_ACS_ELECT 1176
# Observations  SE_ACC_HNDWSH 1165
# Observations  SE_ACS_H2O 1150
# Observations  SE_ACS_CMPTR 1363
# Observations  SE_ACS_INTNT 1312
# Observations  SE_ALP_CPLR 1672
# Observations  SE_GPI_PART 1754
# Observations  SE_TRA_GRDL 2060
# Observations  SE_PRE_PARTN 2386
# Observations  SE_TOT_PRFL 2156
# Observations  SE_AGP_CPRA 3567
# Observations  SE_ADT_EDUCTRN 5305
# Observations  SE_GPI_ICTS 5777
# Observations  SE_TOT_CPLR 15923
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[21], line 8
#       6 for series_code in  series_per_goal[str(goal)]:
#       7     tasks. append(asyncio.ensure_future(get_observations(session, series_code, geocodes )))
# ----> 8 params = await asyncio.gather(*tasks)
#      10 et = time.time()
#      11 elapsed_time = et - st # get the execution time
#
# Cell In[15], line 31, in get_observations(session, series_code, geoAreas)
#      28 obs = 0
#      29 params = []
# ---> 31 async with session.get("https://unstats.un.org/sdgapi/v1/sdg/Series/Data",
#      32                         params = create_params_pages(series_code,geoAreas,str(result['totalElements'])),
#      33                         headers = headers
#      34                     ) as response:
#      35     result = await response.json()
#      36     attributes = metadata_mapping( result['attributes'])
#
# File ~/Library/Caches/pypoetry/virtualenvs/opea-graphrag-example-15Q9BeV4-py3.12/lib/python3.12/site-packages/aiohttp/client.py:1353, in _BaseRequestContextManager.__aenter__(self)
#    1352 async def __aenter__(self) -> _RetType:
# -> 1353     self._resp = await self._coro
#    1354     return self._resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/opea-graphrag-example-15Q9BeV4-py3.12/lib/python3.12/site-packages/aiohttp/client.py:684, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     682 resp = await req.send(conn)
#     683 try:
# --> 684     await resp.start(conn)
#     685 except BaseException:
#     686     resp.close()
#
# File ~/Library/Caches/pypoetry/virtualenvs/opea-graphrag-example-15Q9BeV4-py3.12/lib/python3.12/site-packages/aiohttp/client_reqrep.py:994, in ClientResponse.start(self, connection)
#     991 self._protocol = connection.protocol
#     992 self._connection = connection
# --> 994 with self._timer:
#     995     while True:
#     996         # read response
#     997         try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/opea-graphrag-example-15Q9BeV4-py3.12/lib/python3.12/site-packages/aiohttp/helpers.py:713, in TimerContext.__exit__(self, exc_type, exc_val, exc_tb)
#     710     self._tasks.pop()
#     712 if exc_type is asyncio.CancelledError and self._cancelled:
# --> 713     raise asyncio.TimeoutError from None
#     714 return None
#
# TimeoutError:

# %% [markdown]
# ### Import data  to the SustainGraph using the json file per goal

# %%
def write_obs(tx,statement, params):
    result = tx.run(statement,parameters={"parameters":params})
    return result.data()[0]['total']

# %%
### Neo4j
statement = """ 
    UNWIND $parameters as row
    MATCH (ga:GeoArea),(s:Series{code:row.s_code})
    WHERE row.geo = ga.M49code
    MATCH (src:Source{name:'UN_SDG'})-[:COMES_FROM]-(i:Indicator)-[:HAS_SERIES]->(s)
    MERGE (s)-[:HAS_METADATA]->(sm:SeriesMetadata{attributesCode:row.att_codes,attributesDescription:row.att_desc,
                            dimensionsCode:row.dim_codes,dimensionsDescription:row.dim_desc,seriesCode:row.s_code})
    MERGE (sm)-[:HAS_OBSERVATION{attributesCode:row.att_codes,dimensionsCode:row.dim_codes,
                                seriesCode:row.s_code,time:date(row.year),
                                geoCode:row.geo}]->(o:Observation{time:date(row.year)})
    SET o.value = toFloat(row.value)
    MERGE (o)-[:REFERS_TO_AREA]->(ga)
    MERGE (i) -[:HAS_OBSERVATIONS]->(ga)
    RETURN COUNT(DISTINCT o) as total

"""
for goal in range(1,18):
    print("Goal ", goal)
    f = open(os.path.join(os.getcwd(), "data","2.UN_observations",f"observations{str(goal)}.json"))
    dataToImport = json.load(f)
    print("Start importing to neo4j")
    st = time.time()
    with driver.session() as session:
        for p in dataToImport:
            results = session.execute_write(write_obs,statement, p)
            et = time.time()
            print("Data to be imported: %s" % (len(p)))
            print("Data imported: %s" % results)
            print('---------------------------------------------------')

    elapsed_time = et - st
    print('Import data :', elapsed_time/60, 'minutes')
# Out:
# Goal  1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 20
#      18 for goal in range(1,18):
#      19     print("Goal ", goal)
# ---> 20     f = open(os.path.join(os.getcwd(), "data","2.UN_observations",f"observations{str(goal)}.json"))
#      21     dataToImport = json.load(f)
#      22     print("Start importing to neo4j")
#
# File ~/Library/Caches/pypoetry/virtualenvs/opea-graphrag-example-15Q9BeV4-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/akollegger/Developer/akollegger/genai/opea/GenAIExamples/GraphRAG/notebooks/data/2.UN_observations/observations1.json'

# %% [markdown]
# > Cypher query

# %%
records = driver.execute_query("""\
    MATCH (g:Goal{code:"1"})-[HAS_TARGET]-(t:Target)-[:HAS_INDICATOR]-(i:Indicator)-[:HAS_SERIES]-(s:Series)-[:HAS_METADATA]-(m)-[:HAS_OBSERVATION]-(o:Observation) 
    RETURN g.code AS goal, COUNT(DISTINCT o) AS observations
        """,routing_="r",database_="neo4j",
    result_transformer_=neo4j.Result.to_df)
records
